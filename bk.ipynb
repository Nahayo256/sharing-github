# %%
import matplotlib.pyplot as plt
import numpy as np
matr = np.random.rand(21, 31)
cs = plt.contour(matr)
plt.show()
csf = plt.contourf(matr)
plt.colorbar();
plt.show()

# %%
import numpy as np
x = np.arange(-2, 2, 0.01)
y = np.arange(-2, 2, 0.01)
X, Y = np.meshgrid(x, y)
ellipses = X*X/9 + Y*Y/4 - 1
cs = plt.contour(ellipses)
plt.clabel(cs);
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(-2, 2, 0.01)
y = np.arange(-2, 2, 0.01)
X, Y = np.meshgrid(x, y)
ellipses = X*X/9 + Y*Y/4 - 1
plt.imshow(ellipses);
plt.colorbar();
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax= fig.add_subplot(111)
ax.set_xlim([1, 6]);
ax.set_ylim([1, 9]);
ax.text(2, 8, r"$ \mu \alpha \tau \pi \lambda \omega \tau \lambda \iota \beta $");
ax.text(2, 6, r"$ \lim_{x \rightarrow 0} \frac{1}{x} $");
ax.text(2, 4, r"$ a \ \leq \ b \ \leq \ c \ \Rightarrow \ a \\leq \ c$");
ax.text(2, 2, r"$ \sum_{i=1}^{\infty}\ x_i^2$");
ax.text(4, 8, r"$ \sin(0) = \cos(\frac{\pi}{2})$");
ax.text(4, 6, r"$ \sqrt[3]{x} = \sqrt{y}$");
ax.text(4, 4, r"$ \neg (a \wedge b) \Leftrightarrow \neg a\vee \neg b$");
ax.text(4, 2, r"$ \int_a^b f(x)dx$");
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ParseFatalException                       Traceback (most recent call last)
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\mathtext.py in parse(self, s, fonts_object, fontsize, dpi)
#    2597         try:
# -> 2598             result = self._expression.parseString(s)
#    2599         except ParseBaseException as err:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1827                 # catch and re-raise exception from here, clears out pyparsing internal stack trace
# -> 1828                 raise exc
#    1829         else:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1817         try:
# -> 1818             loc, tokens = self._parse( instring, 0 )
#    1819             if parseAll:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1722                 try:
# -> 1723                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1724                 except ParseBaseException as pe:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1561                 try:
# -> 1562                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1563                 except IndexError:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4097         if self.expr is not None:
# -> 4098             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    4099         else:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1722                 try:
# -> 1723                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1724                 except ParseBaseException as pe:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1561                 try:
# -> 1562                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1563                 except IndexError:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3751             else:
# -> 3752                 loc, exprtokens = e._parse( instring, loc, doActions )
#    3753             if exprtokens or exprtokens.haskeys():
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1722                 try:
# -> 1723                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1724                 except ParseBaseException as pe:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1561                 try:
# -> 1562                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1563                 except IndexError:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4391         try:
# -> 4392             return super(ZeroOrMore, self).parseImpl(instring, loc, doActions)
#    4393         except (ParseException,IndexError):
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4321             try_not_ender(instring, loc)
# -> 4322         loc, tokens = self_expr_parse( instring, loc, doActions, callPreParse=False )
#    4323         try:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1722                 try:
# -> 1723                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1724                 except ParseBaseException as pe:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1561                 try:
# -> 1562                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1563                 except IndexError:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3734         # pre-parsed the string as part of our And pre-parsing
# -> 3735         loc, resultlist = self.exprs[0]._parse( instring, loc, doActions, callPreParse=False )
#    3736         errorStop = False
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1722                 try:
# -> 1723                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1724                 except ParseBaseException as pe:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1594                     try:
# -> 1595                         tokens = fn( instring, tokensStart, retTokens )
#    1596                     except IndexError as parse_action_exc:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in wrapper(*args)
#    1216             try:
# -> 1217                 ret = func(*args[limit[0]:])
#    1218                 foundArity[0] = True
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\mathtext.py in math_string(self, s, loc, toks)
#    2672     def math_string(self, s, loc, toks):
# -> 2673         return self._math_expression.parseString(toks[0][1:-1])
#    2674
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1827                 # catch and re-raise exception from here, clears out pyparsing internal stack trace
# -> 1828                 raise exc
#    1829         else:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1817         try:
# -> 1818             loc, tokens = self._parse( instring, 0 )
#    1819             if parseAll:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1722                 try:
# -> 1723                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1724                 except ParseBaseException as pe:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1561                 try:
# -> 1562                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1563                 except IndexError:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4097         if self.expr is not None:
# -> 4098             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    4099         else:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1722                 try:
# -> 1723                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1724                 except ParseBaseException as pe:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1561                 try:
# -> 1562                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1563                 except IndexError:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4331                     preloc = loc
# -> 4332                 loc, tmptokens = self_expr_parse( instring, preloc, doActions )
#    4333                 if tmptokens or tmptokens.haskeys():
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1722                 try:
# -> 1723                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1724                 except ParseBaseException as pe:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1561                 try:
# -> 1562                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1563                 except IndexError:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4097         if self.expr is not None:
# -> 4098             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    4099         else:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1722                 try:
# -> 1723                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1724                 except ParseBaseException as pe:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1561                 try:
# -> 1562                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1563                 except IndexError:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3901             try:
# -> 3902                 ret = e._parse( instring, loc, doActions )
#    3903                 return ret
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1722                 try:
# -> 1723                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1724                 except ParseBaseException as pe:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1594                     try:
# -> 1595                         tokens = fn( instring, tokensStart, retTokens )
#    1596                     except IndexError as parse_action_exc:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\pyparsing.py in wrapper(*args)
#    1216             try:
# -> 1217                 ret = func(*args[limit[0]:])
#    1218                 foundArity[0] = True
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\mathtext.py in unknown_symbol(self, s, loc, toks)
#    2767         c = toks[0]
# -> 2768         raise ParseFatalException(s, loc, "Unknown symbol: %s" % c)
#    2769
#
# ParseFatalException: Unknown symbol: \ (at char 43), (line:1, col:44)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2054                         orientation=orientation,
#    2055                         dryrun=True,
# -> 2056                         **kwargs)
#    2057                     renderer = self.figure._cachedRenderer
#    2058                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     525
#     526         else:
# --> 527             FigureCanvasAgg.draw(self)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2643             renderer.stop_rasterizing()
#    2644
# -> 2645         mimage._draw_list_compositing_images(renderer, self, artists)
#    2646
#    2647         renderer.close_group('axes')
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\text.py in draw(self, renderer)
#     668
#     669         with _wrap_text(self) as textobj:
# --> 670             bbox, info, descent = textobj._get_layout(renderer)
#     671             trans = textobj.get_transform()
#     672
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     296             if clean_line:
#     297                 w, h, d = renderer.get_text_width_height_descent(
# --> 298                     clean_line, self._fontproperties, ismath=ismath)
#     299             else:
#     300                 w = h = d = 0
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\backends\backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     204         if ismath:
#     205             ox, oy, width, height, descent, fonts, used_characters = \
# --> 206                 self.mathtext_parser.parse(s, self.dpi, prop)
#     207             return width, height, descent
#     208
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\mathtext.py in parse(self, s, dpi, prop)
#    3369             self.__class__._parser = Parser()
#    3370
# -> 3371         box = self._parser.parse(s, font_output, fontsize, dpi)
#    3372         font_output.set_canvas_size(box.width, box.height, box.depth)
#    3373         return font_output.get_results(box)
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\mathtext.py in parse(self, s, fonts_object, fontsize, dpi)
#    2601                                         err.line,
#    2602                                         " " * (err.column - 1) + "^",
# -> 2603                                         str(err)]))
#    2604         self._state_stack = None
#    2605         self._em_width_cache = {}
#
# ValueError:
#  a \ \leq \ b \ \leq \ c \ \Rightarrow \ a \\leq \ c
#                                            ^
# Unknown symbol: \ (at char 43), (line:1, col:44)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['text.usetex'] = True
import numpy as np
x = np.arange(0., 5., .01)
y = [np.sin(2*np.pi*xx) * np.exp(-xx) for xx in x]
plt.plot(x, y, label=r'$\sin(2\pi x)\exp(-x)$');
plt.plot(x, np.exp(-x), label=r'$\exp(-x)$');
plt.plot(x, -np.exp(-x), label=r'$-\exp(-x)$');
plt.title(r'$\sin(2\pi x)\exp(-x)$ with the two asymptotes$\pm\exp(-x)$');
plt.legend();
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\texmanager.py in _run_checked_subprocess(self, command, tex)
#     303                                              cwd=self.texcache,
# --> 304                                              stderr=subprocess.STDOUT)
#     305         except FileNotFoundError as exc:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     471
# --> 472     with Popen(*popenargs, **kwargs) as process:
#     473         try:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     774                                 errread, errwrite,
# --> 775                                 restore_signals, start_new_session)
#     776         except:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1177                                          os.fspath(cwd) if cwd is not None else None,
# -> 1178                                          startupinfo)
#    1179             finally:
#
# FileNotFoundError: [WinError 2] Le fichier spécifié est introuvable
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2054                         orientation=orientation,
#    2055                         dryrun=True,
# -> 2056                         **kwargs)
#    2057                     renderer = self.figure._cachedRenderer
#    2058                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     525
#     526         else:
# --> 527             FigureCanvasAgg.draw(self)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2603                 artists.remove(spine)
#    2604
# -> 2605         self._update_title_position(renderer)
#    2606
#    2607         if not self.axison or inframe:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axes\_base.py in _update_title_position(self, renderer)
#    2552                     # this happens for an empty bb
#    2553                     y = 1
# -> 2554             if title.get_window_extent(renderer).ymin < top:
#    2555                 y = self.transAxes.inverted().transform(
#    2556                         (0., top))[1]
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\text.py in get_window_extent(self, renderer, dpi)
#     888             raise RuntimeError('Cannot get window extent w/o renderer')
#     889
# --> 890         bbox, info, descent = self._get_layout(self._renderer)
#     891         x, y = self.get_unitless_position()
#     892         x, y = self.get_transform().transform_point((x, y))
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     289         _, lp_h, lp_d = renderer.get_text_width_height_descent(
#     290             "lp", self._fontproperties,
# --> 291             ismath="TeX" if self.get_usetex() else False)
#     292         min_dy = (lp_h - lp_d) * self._linespacing
#     293
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\backends\backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     199             fontsize = prop.get_size_in_points()
#     200             w, h, d = texmanager.get_text_width_height_descent(
# --> 201                 s, fontsize, renderer=self)
#     202             return w, h, d
#     203
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     446         else:
#     447             # use dviread. It sometimes returns a wrong descent.
# --> 448             dvifile = self.make_dvi(tex, fontsize)
#     449             with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#     450                 page, = dvi
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\texmanager.py in make_dvi(self, tex, fontsize)
#     336                 self._run_checked_subprocess(
#     337                     ["latex", "-interaction=nonstopmode", "--halt-on-error",
# --> 338                      texfile], tex)
#     339             for fname in glob.glob(basefile + '*'):
#     340                 if not fname.endswith(('dvi', 'tex')):
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\texmanager.py in _run_checked_subprocess(self, command, tex)
#     306             raise RuntimeError(
#     307                 'Failed to process string with tex because {} could not be '
# --> 308                 'found'.format(command[0])) from exc
#     309         except subprocess.CalledProcessError as exc:
#     310             raise RuntimeError(
#
# RuntimeError: Failed to process string with tex because latex could not be found
